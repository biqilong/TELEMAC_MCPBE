# %% [markdown]
# # Refining a mesh
#
# The following script will refine a mesh and its boundary file by dividing each triangle in 4.
# It is using the module stbtel.

# %%
# %%bash
#
# converter.py refine -h
# Out:
# usage: converter.py refine [-h] [-b BND_FILE] [-r ROOT_DIR]
#                            input_file output_file
#
# positional arguments:
#   input_file            name of the input file also defines the input format
#   output_file           name of the output file also defines the output format
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -b BND_FILE, --boundary-file BND_FILE
#                         name of the boundary file
#   -r ROOT_DIR, --root-dir ROOT_DIR
#                         specify the root, default is taken from config file

# %%
# %%bash
#
# cd $HOMETEL/examples/python3/converter
#
# # Running the global refinement
# converter.py refine mesh.slf -b mesh.cli meshx4.slf
# Out:
# Calling: stbtel.py stb.cas
#
#
# Loading Options and Configurations
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#   _                        _
#  | |                      | |
#  | |_  _ __  _   _  _ __  | | __
#  | __|| '__|| | | || '_ \ | |/ /
#  | |_ | |   | |_| || | | ||   <
#   \__||_|    \__,_||_| |_||_|\_\
#
#
#
#
# Running your CAS file(s) for:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# S9.gfortran:
#
#
#     +> Gfortran compiler 6.3.2 with open_mpi for a debian 9
#
#     +> root:    /home/B61570/opentelemac/git/trunk
#     +> module: ad / api / artemis / bief
#                damocles  / gaia  / gretel  / hermes
#                identify_liq_bnd  / khione  / mascaret  / nestor
#                parallel  / partel  / postel3d  / sisyphe
#                special  / stbtel  / telemac2d  / telemac3d
#                tomawac / waqtel
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# ... processing the steering file
#
# ... checking parallelisation
#
# ... handling temporary directories
#          copying: stb.cas -> <root>/examples/python3/converter/stb.cas_2019-10-25-11h14min09s/STBCAS
#          copying: stbtel.dico -> <root>/examples/python3/converter/stb.cas_2019-10-25-11h14min09s/STBDICO
#          copying: mesh.cli -> <root>/examples/python3/converter/stb.cas_2019-10-25-11h14min09s/STBND2
#          copying: mesh.slf -> <root>/examples/python3/converter/stb.cas_2019-10-25-11h14min09s/STBGEO
#
# ... checking the executable
#
#
# Running your simulation(s) :
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# In /home/B61570/opentelemac/git/trunk/examples/python3/converter/stb.cas_2019-10-25-11h14min09s:
# mpirun -np 1 /home/B61570/opentelemac/git/trunk/examples/python3/converter/stb.cas_2019-10-25-11h14min09s/out_stbtel
#
#
#  MASTER PROCESSOR NUMBER            0  OF THE GROUP OF            1
#  EXECUTABLE FILE: /home/B61570/opentelemac/git/trunk/examples/python3/converter/stb.cas_2019-10-25-11h14min09s/A.EXE
#  LISTING OF STBTEL------------------------------------------------------------------------------
#
#                  SSSSS  TTTTT  BBBB   TTTTT  EEEEE  L
#                  S        T    B   B    T    E      L
#                  SSSSS    T    BBBB     T    EEEE   L
#                      S    T    B   B    T    E      L
#                  SSSSS    T    BBBB     T    EEEEE  LLLLL
#
#                        VERSION TRUNK  FORTRAN 2003
#
#                   *     *    *     /\__/\  *    ---    *
#                      *            /      \    /     \
#                           *   *  |  -  -  |  |       |*
#                    *   __________| \     /|  |       |
#                      /              \ T / |   \     /
#                    /                      |  *  ---
#                   |  ||     |    |       /             *
#                   |  ||    /______\     / |*     *
#                   |  | \  |  /     \   /  |
#                    \/   | |\ \      | | \ \
#                         | | \ \     | |  \ \
#                         | |  \ \    | |   \ \
#                         '''   '''   '''    '''
#
#  NPTFR FROM LECSEL         1080
#  NPTFR FROM LECSELLIM         1080
#
#  MESH GENERATOR : SELAFIN
#  --------------
#
#  DATAS READ IN THE UNIVERSAL FILE
#  ---------------------------------
#
#  TITLE OF THE MESH                 : TELEMAC 2D : RUPTURE DE BARRAGE SUR FOND SEC$
#  REAL NUMBER OF POINTS             :       13541
#  MAX. NUMBER GIVEN BY THE MESH GENERATOR:       13541
#  TOTAL NUMBER OF ELEMENTS           :       26000
#  TYPE OF ELEMENTS                   :      TRIANGLES
#
#  CUTTING ELEMENTS BY 4
#  ---------------------
#
#  NEW NUMBER OF POINTS   :     53081
#  NEW NUMBER OF ELEMENTS :    104000
#  NUMBER OF BOUNDARY POINTS      :  2160
#  NUMBER OF ISLANDS              :     0
#
#  ELIMINATION OK BACKWARDS DEPENDENCIES
#  ------------------------------------
#
#  BACKWARD DEPENDENCIES ARE CANCELLED AFTER  0 ATTEMPTS
#
#  GENERATING GEOMETRY FILE
#  ------------------------
#
#  TREATMENT OF BOUNDARY CONDITIONS
#  --------------------------------
#
#  CORRECT END OF RUN
#
#  COMPUTER TIME:            0  SECONDS
#
#  EXITING MPI
#
# STOP 0
# ... merging separated result files
#
# ... handling result files
#
#         moving: meshx4.cli
#         moving: meshx4.slf
# ... deleting working dir
#
#
#
# My work is done

# %% [markdown]
# We will now make a diff between the scan of the two files

# %%
# %%bash
#
# cd $HOMETEL/examples/python3/converter
#
# run_selafin.py scan mesh.slf > init.log
# run_selafin.py scan meshx4.slf > modif.log
#
# colordiff init.log modif.log
#
# echo
# Out:
# 8c8
# < Scanning mesh.slf within /home/B61570/opentelemac/git/trunk/examples/python3/converter
# ---
# > Scanning meshx4.slf within /home/B61570/opentelemac/git/trunk/examples/python3/converter
# 14c14
# < title        :    <TELEMAC 2D : RUPTURE DE BARRAGE SUR FOND SEC$                           SERAPHIN>
# ---
# > title        :    <TELEMAC 2D : RUPTURE DE BARRAGE SUR FOND SEC$                           SERAFIN >
# 27c27
# <    - nptfr* = 0
# ---
# >    - nptfr* = 2160
# 29,30c29,30
# <    - nelem3 = 26000
# <    - npoin3 = 13541
# ---
# >    - nelem3 = 104000
# >    - npoin3 = 53081
# 35,37c35,37
# <    - ikle  : / min: [ 1 ]  / max: [ 13541 ] [[ 2193   962  2191]
# <  [ 1103  2189   648]
# <  [12311 12298 13357]
# ---
# >    - ikle  : / min: [ 1 ]  / max: [ 53081 ] [[52825 14728 15977]
# >  [ 1103 13545 13547]
# >  [15172 14440 13917]
# 39,42c39,42
# <  [ 4242  2458  4272]
# <  [ 2608  2573  1943]
# <  [11452  2148 11451]]
# <    - ipobo  : / min: [ 0 ]  / max: [ 1080 ] [763 765 908 ...   0   0   0]
# ---
# >  [12311 13548 13550]
# >  [52793 33037 52892]
# >  [ 2193 13542 13544]]
# >    - ipobo  : / min: [ 0 ]  / max: [ 2160 ] [1525 1529 1815 ... 1654 1608 2020]
