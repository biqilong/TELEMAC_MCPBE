# %% [markdown]
# # Difference between two SERAFIN files
#
# Two tools are available do check the difference between two SERAFIN files:
#   * A comparaison of what is different between the two files
#   * Creating  a new file that contains for each variable each time step data from file 1 - data from file2
#
# ## Diff information
#
# For that we use the script **diff_selafin.py**.

# %%
# %%bash
#
# diff_selafin.py --help
# Out:
# Loading Options and Configurations
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# usage:  (--help for help)
# ---------
#       =>  diff_selafin.py [options] file1.slf file2.slf
# ---------
#
# Reporting on differences between two SELAFIN files
#
#
# positional arguments:
#   file1,file2           operation: ( files1 - file2 )
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --head                Will print a statiscal differences between two
#                         SELARING files
#   --core                Will print a statiscal differences between two
#                         SELARING files
#   --scan                Will print an individual summary for each file
#   -v XVARS, --vars XVARS
#                         specify which variables should be differentiated
#                         (':'-delimited)
#   -f TFROM, --from TFROM
#                         specify the first frame included in the
# ...

# %%
# %%bash
#
# cd $HOMETEL/examples/telemac2d/gouttedo
#
# diff_selafin.py f2d_gouttedo.slf f2d_gouttedo_cin.slf --head --core
# Out:
# Loading Options and Configurations
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Header differences:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#   <> List of variable names:
#
#      + f2d_gouttedo.slf
#         = VELOCITY U
#         = VELOCITY V
#         = WATER DEPTH
#      + f2d_gouttedo_cin.slf
#         = VELOCITY U
#         = VELOCITY V
#         = WATER DEPTH
#         * TRACER 1
#
#   <> List of time frames:
#
#      + frames only in f2d_gouttedo.slf : 0.20, 0.40, 0.60, 0.80, 1.00, 1.20, 1.40, 1.60, 1.80, 2.00, 2.20, 2.40, 2.60, 2.80, 3.00, 3.20, 3.40, 3.60, 3.80
#      + frames only in f2d_gouttedo_cin.slf : 0.35, 0.70, 1.05, 1.40, 1.74, 2.08, 2.37, 2.68, 3.01, 3.36, 3.71
#      + frames in both files: 0.0, 4.0
#
#   <> List of time frames:
#
#      + frames only in f2d_gouttedo.slf : 0.20, 0.40, 0.60, 0.80, 1.00, 1.20, 1.40, 1.60, 1.80, 2.00, 2.20, 2.40, 2.60, 2.80, 3.00, 3.20, 3.40, 3.60, 3.80
# ...

# %% [markdown]
# ## Diff in a file
#
# For that we use the script **run_selafin.py diff**.
#
# The files must have the same mesh.
#
# For the variable and the time steps it will only keep the ones that are only in both file.

# %%
# %%bash
#
# run_selafin.py diff -h
# Out:
# Interpreting command line options
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# usage: run_selafin.py diff [-h] SELAFIN file SELAFIN file SELAFIN file
#
# positional arguments:
#   SELAFIN file
#
# optional arguments:
#   -h, --help    show this help message and exit

# %%
# %%bash
#
# cd $HOMETEL/examples/telemac2d/malpasset
#
# run_selafin.py diff f2d_malpasset-char.slf f2d_malpasset-kin1.slf diff.slf
#
# run_selafin.py scan --core f2d_malpasset-char.slf > file1.log
# run_selafin.py scan --core f2d_malpasset-kin1.slf > file2.log
#
# run_selafin.py scan --core diff.slf
#
# colordiff file1.log file2.log
#
# echo
# Out:
# Interpreting command line options
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Differences into diff.slf
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# My work is done
#
#
#
#
# Interpreting command line options
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Scanning diff.slf within /home/B61570/opentelemac/git/trunk/examples/telemac2d/malpasset
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# This file appears to be coded in "big endian"
#      and the floats are assumed to be SINGLE PRECISION
#
# title        :    <CHERACTERISTICS SCHEME (WAVE EQ.)                                       SERAFIN >
# Date / Time  : 1-1-1900 0:0:0
# Variables    :
#    - VELOCITY U      M/S
#    - VELOCITY V      M/S
#    - WATER DEPTH     M
#    - FREE SURFACE    M
#    - BOTTOM          M
# NUMBERs      :
#    - nplan* = 0
#    - nptfr* = 1080
#    - iface* = 0
# ...
