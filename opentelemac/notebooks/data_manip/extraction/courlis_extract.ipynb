# %% [markdown]
# # Courlis scripts
#
# ## Extract bottom state from ptravers result file
#
# The script `converter.py extract_ptravers_res_to_geoc` allows to extract a bottom and layer state from ptravers file to a Courlis geometry file (`.geoC`) which can be used to do a new Courlis simulation beginning from this state. It can be used also to perform a Mascaret simulation with a geometry from Courlis.

# %%
# %%bash
#
# converter.py extract_ptravers_res_to_geoc -h
# Out:
# usage: converter.py extract_ptravers_res_to_geoc [-h] [-o OUTPUTFILENAME]
#                                                  [-r RECORD]
#                                                  ptravers Courlis file
#
# positional arguments:
#   ptravers Courlis file
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -o OUTPUTFILENAME, --output OUTPUTFILENAME
#                         Option to give a name to the output Courlis geometry
#                         file
#   -r RECORD, --time-record RECORD
#                         Record number of the state you want extract from
#                         ptravers to a geometry courlis file

# %%
# %%bash
#
# # Run Soni
# cd $HOMETEL/examples/courlis/Soni && mascaret.py sarap.xcas
# Out:
# Loading Options and Configurations
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
# Loading Options and Configurations
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#   _                        _
#  | |                      | |
#  | |_  _ __  _   _  _ __  | | __
#  | __|| '__|| | | || '_ \ | |/ /
#  | |_ | |   | |_| || | | ||   <
#   \__||_|    \__,_||_| |_||_|\_\
#
#
# ~+> Creating FichierCas.txt
#  Fichiercas : FichierCas.txt
#
#  MASCARET v8.1.4 == Copyright (C) 2000-2017 EDF-CEREMA ==
#
#  Data File : sarap.xcas
#
#  T
#  hydro_courlis.cas
#
#  Clip Evolution = 0.5000E-01
#
#  Pente locale : F
#
#  Attention, diametres nuls ou non renseignes dans le fichier cas
#  Utilisation de formules a partir du d50 pour determiner les diametres ci-dessous :
#
#  Parametres utilises seulement pour les formules de transport de Recking et de Lefort
#  D84 = 0.6720E-03
#  Diametre moyen = 0.3520E-03
#
# ...

# %% [markdown]
# Output file (`-o` or `--output` arguments) is optional (an automatic name will be attributed `inputfilename_listingcourlis.opt`)
#
# Option record alows to select the time frame to extract (by default last time step of ptravers file is extracted)

# %%
# %%bash
#
# cd $HOMETEL/examples/courlis/Soni
#
# converter.py extract_ptravers_res_to_geoc resu.ptravers -r 50
# Out:
# Extracting time 2450.0s from resu.ptravers to _prev.geoC

# %% [markdown]
# To get the number of a time frame in a ptravers file, `MascaretFile.summary()` can be used (last section of the summary):

# %%
import os.path
from data_manip.formats.mascaret_file import MascaretFile

courlis_file = MascaretFile(os.path.join(os.environ['HOMETEL'], 'examples', 'courlis', 'Soni', 'resu.ptravers'))
print(courlis_file.summary())
# Out:
# ~> MascaretFile: /home/B61570/opentelemac/git/trunk/examples/courlis/Soni/resu.ptravers (mode=r)
#     - Reach #1 (Reach_1) with 121 sections
#         0) Section #1 (Profil_1) at pk 0.000000
#         1) Section #2 (Profil_2) at pk 0.250000
#         2) Section #3 (Profil_3) at pk 0.500000
#         3) Section #4 (Profil_4) at pk 0.750000
#         4) Section #5 (Profil_5) at pk 1.000000
#         5) Section #6 (Profil_6) at pk 1.250000
#         6) Section #7 (Profil_7) at pk 1.500000
#         7) Section #8 (Profil_8) at pk 1.750000
#         8) Section #9 (Profil_9) at pk 2.000000
#         9) Section #10 (Profil_10) at pk 2.250000
#         10) Section #11 (Profil_11) at pk 2.500000
#         11) Section #12 (Profil_12) at pk 2.750000
#         12) Section #13 (Profil_13) at pk 3.000000
#         13) Section #14 (Profil_14) at pk 3.250000
#         14) Section #15 (Profil_15) at pk 3.500000
#         15) Section #16 (Profil_16) at pk 3.750000
# ...
